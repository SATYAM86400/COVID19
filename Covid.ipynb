# %%
from covid import Covid

# %%
covid = Covid()

# %%
# covid.get_data()
countries = covid.list_countries()

# %%
# print(countries)

# %%
# covid.get_data()

# %%
india_cases = covid.get_status_by_country_name('india')

# %%
print(india_cases)
# Out:
# {'id': '94', 'country': 'India', 'confirmed': 247857, 'active': 121610, 'deaths': 6954, 'recovered': 119293, 'latitude': 20.593684, 'longitude': 78.96288, 'last_update': 1591529606000}

# %%
active = covid.get_total_active_cases()

# %%
print(active)
# Out:
# 3471989

# %%
covid = Covid(source="worldometers")

# %%
covid.get_data()
# Out:
# [{'country': 'North America',
#   'confirmed': 2258189,
#   'new_cases': 4322,
#   'deaths': 135133,
#   'recovered': 916819,
#   'active': 1206237,
#   'critical': 19440,
#   'new_deaths': 362,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'South America',
#   'confirmed': 1117287,
#   'new_cases': 3537,
#   'deaths': 48871,
#   'recovered': 526023,
#   'active': 542393,
#   'critical': 11778,
#   'new_deaths': 114,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Europe',
#   'confirmed': 2089786,
#   'new_cases': 11054,
#   'deaths': 178761,
#   'recovered': 1080781,
#   'active': 830244,
#   'critical': 7199,
#   'new_deaths': 178,
#   'total_tests': 0,
# ...

# %%
covid.get_status_by_country_name('india')
# Out:
# {'country': 'India',
#  'confirmed': 247857,
#  'new_cases': 1235,
#  'deaths': 6954,
#  'recovered': 119293,
#  'active': 121610,
#  'critical': 8944,
#  'new_deaths': 8,
#  'total_tests': 4666386,
#  'total_tests_per_million': Decimal('0'),
#  'total_cases_per_million': Decimal('180'),
#  'total_deaths_per_million': Decimal('5'),
#  'population': Decimal('1379085538')}

# %%
covid.list_countries()
# Out:
# ['north america',
#  'south america',
#  'europe',
#  'asia',
#  'africa',
#  'oceania',
#  '',
#  'world',
#  'usa',
#  'brazil',
#  'russia',
#  'spain',
#  'uk',
#  'india',
#  'italy',
#  'peru',
#  'germany',
#  'iran',
#  'turkey',
#  'france',
#  'chile',
#  'mexico',
#  'pakistan',
#  'saudi arabia',
#  'canada',
#  'qatar',
#  'bangladesh',
#  'belgium',
#  'belarus',
#  'netherlands',
#  'south africa',
#  'sweden',
#  'ecuador',
#  'uae',
#  'colombia',
#  'singapore',
#  'portugal',
#  'egypt',
#  'kuwait',
#  'indonesia',
#  'switzerland',
#  'ukraine',
#  'poland',
#  'ireland',
#  'argentina',
#  'philippines',
#  'romania',
#  'afghanistan',
#  'dominican republic',
#  'israel',
#  'japan',
#  'austria',
#  'oman',
#  'panama',
#  'bahrain',
#  'bolivia',
#  'armenia',
#  'kazakhstan',
#  'nigeria',
#  'denmark',
#  's. korea',
#  'serbia',
#  'iraq',
#  'algeria',
#  'czechia',
#  'moldova',
#  'ghana',
#  'norway',
#  'malaysia',
#  'morocco',
#  'cameroon',
# ...

# %%
print(covid.get_status_by_country_name('india').get('recovered'))
# Out:
# 119293

# %%
country = str(input("Enter the country you want the data of : "))
# Out:
# Enter the country you want the data of : USA

# %%
import pprint

pp = pprint.PrettyPrinter(indent=4)
pp.pprint(covid.get_status_by_country_name(country))
# Out:
# {   'active': 1124551,
#     'confirmed': 1988700,
#     'country': 'USA',
#     'critical': 17016,
#     'deaths': 112101,
#     'new_cases': 156,
#     'new_deaths': 5,
#     'population': Decimal('330875237'),
#     'recovered': 752048,
#     'total_cases_per_million': Decimal('6010'),
#     'total_deaths_per_million': Decimal('339'),
#     'total_tests': 20819906,
#     'total_tests_per_million': Decimal('0')}

# %%
covid.list_countries()
# Out:
# ['north america',
#  'south america',
#  'europe',
#  'asia',
#  'africa',
#  'oceania',
#  '',
#  'world',
#  'usa',
#  'brazil',
#  'russia',
#  'spain',
#  'uk',
#  'india',
#  'italy',
#  'peru',
#  'germany',
#  'iran',
#  'turkey',
#  'france',
#  'chile',
#  'mexico',
#  'pakistan',
#  'saudi arabia',
#  'canada',
#  'qatar',
#  'bangladesh',
#  'belgium',
#  'belarus',
#  'netherlands',
#  'south africa',
#  'sweden',
#  'ecuador',
#  'uae',
#  'colombia',
#  'singapore',
#  'portugal',
#  'egypt',
#  'kuwait',
#  'indonesia',
#  'switzerland',
#  'ukraine',
#  'poland',
#  'ireland',
#  'argentina',
#  'philippines',
#  'romania',
#  'afghanistan',
#  'dominican republic',
#  'israel',
#  'japan',
#  'austria',
#  'oman',
#  'panama',
#  'bahrain',
#  'bolivia',
#  'armenia',
#  'kazakhstan',
#  'nigeria',
#  'denmark',
#  's. korea',
#  'serbia',
#  'iraq',
#  'algeria',
#  'czechia',
#  'moldova',
#  'ghana',
#  'norway',
#  'malaysia',
#  'morocco',
#  'cameroon',
# ...
