# %%
from covid import Covid

# %%
covid = Covid()
# covid.get_data()

# %%
# covid.get_data()
countries = covid.list_countries()

# %%
print(countries)
# Out:
# [{'id': '18', 'name': 'US'}, {'id': '22', 'name': 'Brazil'}, {'id': '14', 'name': 'Russia'}, {'id': '17', 'name': 'United Kingdom'}, {'id': '94', 'name': 'India'}, {'id': '19', 'name': 'Spain'}, {'id': '11', 'name': 'Italy'}, {'id': '23', 'name': 'Peru'}, {'id': '7', 'name': 'France'}, {'id': '8', 'name': 'Germany'}, {'id': '96', 'name': 'Iran'}, {'id': '177', 'name': 'Turkey'}, {'id': '21', 'name': 'Chile'}, {'id': '20', 'name': 'Mexico'}, {'id': '154', 'name': 'Saudi Arabia'}, {'id': '139', 'name': 'Pakistan'}, {'id': '3', 'name': 'Canada'}, {'id': '4', 'name': 'China'}, {'id': '146', 'name': 'Qatar'}, {'id': '38', 'name': 'Bangladesh'}, {'id': '41', 'name': 'Belgium'}, {'id': '40', 'name': 'Belarus'}, {'id': '163', 'name': 'South Africa'}, {'id': '12', 'name': 'Netherlands'}, {'id': '15', 'name': 'Sweden'}, {'id': '71', 'name': 'Ecuador'}, {'id': '179', 'name': 'United Arab Emirates'}, {'id': '24', 'name': 'Colombia'}, {'id': '159', 'name': 'Singapore'}, {'id': '145', 'name': 'Portugal'}, {'id': '72', 'name': 'Egypt'}, {'id': '105', 'name': 'Kuwait'}, {'id': '95', 'name': 'Indonesia'}, {'id': '16', 'name': 'Switzerland'}, {'id': '26', 'name': 'Ukraine'}, {'id': '144', 'name': 'Poland'}, {'id': '10', 'name': 'Ireland'}, {'id': '33', 'name': 'Argentina'}, {'id': '143', 'name': 'Philippines'}, {'id': '27', 'name': 'Afghanistan'}, {'id': '147', 'name': 'Romania'}, {'id': '70', 'name': 'Dominican Republic'}, {'id': '98', 'name': 'Israel'}, {'id': '138', 'name': 'Oman'}, {'id': '25', 'name': 'Japan'}, {'id': '2', 'name': 'Austria'}, {'id': '140', 'name': 'Panama'}, {'id': '37', 'name': 'Bahrain'}, {'id': '45', 'name': 'Bolivia'}, {'id': '97', 'name': 'Iraq'}, {'id': '34', 'name': 'Armenia'}, {'id': '101', 'name': 'Kazakhstan'}, {'id': '136', 'name': 'Nigeria'}, {'id': '5', 'name': 'Denmark'}, {'id': '156', 'name': 'Serbia'}, {'id': '103', 'name': 'Korea, South'}, {'id': '29', 'name': 'Algeria'}, {'id': '125', 'name': 'Moldova'}, {'id': '66', 'name': 'Czechia'}, {'id': '83', 'name': 'Ghana'}, {'id': '13', 'name': 'Norway'}, {'id': '119', 'name': 'Malaysia'}, {'id': '129', 'name': 'Morocco'}, {'id': '55', 'name': 'Cameroon'}, {'id': '35', 'name': 'Azerbaijan'}, {'id': '1', 'name': 'Australia'}, {'id': '86', 'name': 'Guatemala'}, {'id': '6', 'name': 'Finland'}, {'id': '92', 'name': 'Honduras'}, {'id': '166', 'name': 'Sudan'}, {'id': '170', 'name': 'Tajikistan'}, {'id': '181', 'name': 'Uzbekistan'}, {'id': '155', 'name': 'Senegal'}, {'id': '68', 'name': 'Djibouti'}, {'id': '87', 'name': 'Guinea'}, {'id': '60', 'name': 'Congo (Kinshasa)'}, {'id': '115', 'name': 'Luxembourg'}, {'id': '93', 'name': 'Hungary'}, {'id': '132', 'name': 'Nepal'}, {'id': '62', 'name': "Cote d'Ivoire"}, {'id': '90', 'name': 'Haiti'}, {'id': '137', 'name': 'North Macedonia'}, {'id': '172', 'name': 'Thailand'}, {'id': '73', 'name': 'El Salvador'}, {'id': '80', 'name': 'Gabon'}, {'id': '84', 'name': 'Greece'}, {'id': '102', 'name': 'Kenya'}, {'id': '49', 'name': 'Bulgaria'}, {'id': '46', 'name': 'Bosnia and Herzegovina'}, {'id': '182', 'name': 'Venezuela'}, {'id': '162', 'name': 'Somalia'}, {'id': '63', 'name': 'Croatia'}, {'id': '64', 'name': 'Cuba'}, {'id': '78', 'name': 'Ethiopia'}, {'id': '106', 'name': 'Kyrgyzstan'}, {'id': '76', 'name': 'Estonia'}, {'id': '120', 'name': 'Maldives'}, {'id': '165', 'name': 'Sri Lanka'}, {'id': '9', 'name': 'Iceland'}, {'id': '114', 'name': 'Lithuania'}, {'id': '56', 'name': 'Central African Republic'}, {'id': '164', 'name': 'South Sudan'}, {'id': '121', 'name': 'Mali'}, {'id': '160', 'name': 'Slovakia'}, {'id': '133', 'name': 'New Zealand'}, {'id': '161', 'name': 'Slovenia'}, {'id': '88', 'name': 'Guinea-Bissau'}, {'id': '109', 'name': 'Lebanon'}, {'id': '61', 'name': 'Costa Rica'}, {'id': '74', 'name': 'Equatorial Guinea'}, {'id': '28', 'name': 'Albania'}, {'id': '187', 'name': 'Zambia'}, {'id': '142', 'name': 'Paraguay'}, {'id': '104', 'name': 'Kosovo'}, {'id': '134', 'name': 'Nicaragua'}, {'id': '117', 'name': 'Madagascar' ...

# %%
india_cases = covid.get_status_by_country_name('india')

# %%
print(india_cases)
# Out:
# {'id': '94', 'country': 'India', 'confirmed': 265869, 'active': 129308, 'deaths': 7473, 'recovered': 129088, 'latitude': 20.593684, 'longitude': 78.96288, 'last_update': 1591641212000}

# %%
active = covid.get_total_active_cases()

# %%
print(active)
# Out:
# 3479953

# %%
covid = Covid(source="worldometers")

# %%
covid.get_data()
# Out:
# [{'country': 'North America',
#   'confirmed': 2294855,
#   'new_cases': 16375,
#   'deaths': 136164,
#   'recovered': 936214,
#   'active': 1222477,
#   'critical': 19416,
#   'new_deaths': 627,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'South America',
#   'confirmed': 1153919,
#   'new_cases': 7449,
#   'deaths': 51149,
#   'recovered': 531989,
#   'active': 570781,
#   'critical': 11793,
#   'new_deaths': 927,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Europe',
#   'confirmed': 2109056,
#   'new_cases': 14346,
#   'deaths': 179356,
#   'recovered': 1088861,
#   'active': 840839,
#   'critical': 7116,
#   'new_deaths': 413,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Asia',
#   'confirmed': 1392377,
#   'new_cases': 31148,
#   'deaths': 35639,
#   'recovered': 842895,
#   'active': 513843,
#   'critical': 14951,
#   'new_deaths': 614,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Africa',
#   'confirmed': 196773,
#   'new_cases': 4655,
#   'deaths': 5330,
#   'recovered': 87548,
#   'active': 103895,
#   'critical': 485,
#   'new_deaths': 113,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Oceania',
#   'confirmed': 8875,
#   'new_cases': 5,
#   'deaths': 124,
#   'recovered': 8293,
#   'active': 458,
#   'critical': 3,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': '0',
#   'confirmed': 721,
#   'new_cases': 0,
#   'deaths': 15,
#   'recovered': 651,
#   'active': 55,
#   'critical': 4,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'World',
#   'confirmed': 7156576,
#   'new_cases': 73978,
#   'deaths': 407777,
#   'recovered': 3496451,
#   'active': 3252348,
#   'critical': 53768,
#   'new_deaths': 2694,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('918'),
#   'total_deaths_per_million': Decimal('52.3'),
#   'population': Decimal('0')},
#  {'country': 'USA',
#   'confirmed': 2018552,
#   'new_cases': 11103,
#   'deaths': 112844,
#   'recovered': 767144,
#   'active': 1138564,
#   'critical': 16897,
#   'new_deaths': 375,
#   'total_tests': 21558358,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('6101'),
#   'total_deaths_per_million': Decimal('341'),
#   'population': Decimal('330880530')},
#  {'country': 'Brazil',
#   'confirmed': 694116,
#   'new_cases': 2154,
#   'deaths': 37312,
#   'recovered': 302084,
#   'active': 354720,
#   'critical': 8318,
#   'new_deaths': 813,
#   'total_tests': 999836,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3267'),
#   'total_deaths_per_million': Decimal('176'),
#   'population': Decimal('212463372')},
#  {'country': 'Russia',
#   'confirmed': 476658,
#   'new_cases': 8985,
#   'deaths': 5971,
#   'recovered': 230688,
#   'active': 239999,
#   'critical': 2300,
#   'new_deaths': 112,
#   'total_tests': 13016023,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3266'),
#   'total_deaths_per_million': Decimal('41'),
#   'population': Decimal('145930700')},
#  {'country': 'Spain',
#   'confirmed': 288797,
#   'new_cases': 167,
#   'deaths': 27136,
#   'recovered': 0,
#   'active': 0,
#   'critical': 617,
#   'new_deaths': 0,
#   'total_tests': 4465338,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('6177'),
#   'total_deaths_per_million': Decimal('580'),
#   'population': Decimal('46753690')},
#  {'country': 'UK',
#   'confirmed': 287399,
#   'new_cases': 1205,
#   'deaths': 40597,
#   'recovered': 0,
#   'active': 0,
#   'critical': 516,
#   'new_deaths': 55,
#   'total_tests': 5731576,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4235'),
#   'total_deaths_per_million': Decimal('598'),
#   'population': Decimal('67863688')},
#  {'country': 'India',
#   'confirmed': 265869,
#   'new_cases': 8383,
#   'deaths': 7473,
#   'recovered': 129088,
#   'active': 129308,
#   'critical': 8944,
#   'new_deaths': 266,
#   'total_tests': 4774434,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('193'),
#   'total_deaths_per_million': Decimal('5'),
#   'population': Decimal('1379122578')},
#  {'country': 'Italy',
#   'confirmed': 235278,
#   'new_cases': 280,
#   'deaths': 33964,
#   'recovered': 166584,
#   'active': 34730,
#   'critical': 283,
#   'new_deaths': 65,
#   'total_tests': 4236535,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3891'),
#   'total_deaths_per_million': Decimal('562'),
#   'population': Decimal('60467085')},
#  {'country': 'Peru',
#   'confirmed': 196515,
#   'new_cases': 0,
#   'deaths': 5465,
#   'recovered': 86219,
#   'active': 104831,
#   'critical': 1062,
#   'new_deaths': 0,
#   'total_tests': 1191956,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5966'),
#   'total_deaths_per_million': Decimal('166'),
#   'population': Decimal('32941004')},
#  {'country': 'Germany',
#   'confirmed': 186193,
#   'new_cases': 324,
#   'deaths': 8783,
#   'recovered': 169600,
#   'active': 7810,
#   'critical': 540,
#   'new_deaths': 7,
#   'total_tests': 4348880,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2223'),
#   'total_deaths_per_million': Decimal('105'),
#   'population': Decimal('83767456')},
#  {'country': 'Iran',
#   'confirmed': 173832,
#   'new_cases': 2043,
#   'deaths': 8351,
#   'recovered': 136360,
#   'active': 29121,
#   'critical': 2619,
#   'new_deaths': 70,
#   'total_tests': 1107254,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2071'),
#   'total_deaths_per_million': Decimal('100'),
#   'population': Decimal('83921387')},
#  {'country': 'Turkey',
#   'confirmed': 171121,
#   'new_cases': 989,
#   'deaths': 4711,
#   'recovered': 141380,
#   'active': 25030,
#   'critical': 625,
#   'new_deaths': 19,
#   'total_tests': 2377954,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2030'),
#   'total_deaths_per_million': Decimal('56'),
#   'population': Decimal('84279639')},
#  {'country': 'France',
#   'confirmed': 154188,
#   'new_cases': 211,
#   'deaths': 29209,
#   'recovered': 71062,
#   'active': 53917,
#   'critical': 1024,
#   'new_deaths': 54,
#   'total_tests': 1384633,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2363'),
#   'total_deaths_per_million': Decimal('448'),
#   'population': Decimal('65264696')},
#  {'country': 'Chile',
#   'confirmed': 138846,
#   'new_cases': 4696,
#   'deaths': 2264,
#   'recovered': 95631,
#   'active': 40951,
#   'critical': 1558,
#   'new_deaths': 74,
#   'total_tests': 728815,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('7267'),
#   'total_deaths_per_million': Decimal('118'),
#   'population': Decimal('19105644')},
#  {'country': 'Mexico',
#   'confirmed': 117103,
#   'new_cases': 3484,
#   'deaths': 13699,
#   'recovered': 84419,
#   'active': 18985,
#   'critical': 378,
#   'new_deaths': 188,
#   'total_tests': 336395,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('909'),
#   'total_deaths_per_million': Decimal('106'),
#   'population': Decimal('128844230')},
#  {'country': 'Saudi Arabia',
#   'confirmed': 105283,
#   'new_cases': 3369,
#   'deaths': 746,
#   'recovered': 74524,
#   'active': 30013,
#   'critical': 1632,
#   'new_deaths': 34,
#   'total_tests': 976815,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3027'),
#   'total_deaths_per_million': Decimal('21'),
#   'population': Decimal('34776977')},
#  {'country': 'Pakistan',
#   'confirmed': 103671,
#   'new_cases': 4728,
#   'deaths': 2067,
#   'recovered': 34355,
#   'active': 67249,
#   'critical': 111,
#   'new_deaths': 65,
#   'total_tests': 705833,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('470'),
#   'total_deaths_per_million': Decimal('9'),
#   'population': Decimal('220591553')},
#  {'country': 'Canada',
#   'confirmed': 96140,
#   'new_cases': 441,
#   'deaths': 7830,
#   'recovered': 54473,
#   'active': 33837,
#   'critical': 1816,
#   'new_deaths': 30,
#   'total_tests': 1896822,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2549'),
#   'total_deaths_per_million': Decimal('208'),
#   'population': Decimal('37720832')},
#  {'country': 'Qatar',
#   'confirmed': 70158,
#   'new_cases': 1368,
#   'deaths': 57,
#   'recovered': 45935,
#   'active': 24166,
#   'critical': 241,
#   'new_deaths': 3,
#   'total_tests': 259646,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('24987'),
#   'total_deaths_per_million': Decimal('20'),
#   'population': Decimal('2807805')},
#  {'country': 'Bangladesh',
#   'confirmed': 68504,
#   'new_cases': 2735,
#   'deaths': 930,
#   'recovered': 14560,
#   'active': 53014,
#   'critical': 1,
#   'new_deaths': 42,
#   'total_tests': 410841,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('416'),
#   'total_deaths_per_million': Decimal('6'),
#   'population': Decimal('164582631')},
#  {'country': 'Belgium',
#   'confirmed': 59348,
#   'new_cases': 122,
#   'deaths': 9606,
#   'recovered': 16315,
#   'active': 33427,
#   'critical': 116,
#   'new_deaths': 11,
#   'total_tests': 949675,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5122'),
#   'total_deaths_per_million': Decimal('829'),
#   'population': Decimal('11586489')},
#  {'country': 'South Africa',
#   'confirmed': 50879,
#   'new_cases': 2594,
#   'deaths': 1080,
#   'recovered': 26099,
#   'active': 23700,
#   'critical': 208,
#   'new_deaths': 82,
#   'total_tests': 943059,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('859'),
#   'total_deaths_per_million': Decimal('18'),
#   'population': Decimal('59258991')},
#  {'country': 'Belarus',
#   'confirmed': 49453,
#   'new_cases': 823,
#   'deaths': 276,
#   'recovered': 23880,
#   'active': 25297,
#   'critical': 92,
#   'new_deaths': 7,
#   'total_tests': 632993,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5233'),
#   'total_deaths_per_million': Decimal('29'),
#   'population': Decimal('9449509')},
#  {'country': 'Netherlands',
#   'confirmed': 47739,
#   'new_cases': 165,
#   'deaths': 6016,
#   'recovered': 0,
#   'active': 0,
#   'critical': 92,
#   'new_deaths': 3,
#   'total_tests': 414550,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2786'),
#   'total_deaths_per_million': Decimal('351'),
#   'population': Decimal('17132558')},
#  {'country': 'Sweden',
#   'confirmed': 45133,
#   'new_cases': 68,
#   'deaths': 4694,
#   'recovered': 0,
#   'active': 0,
#   'critical': 298,
#   'new_deaths': 35,
#   'total_tests': 275500,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4471'),
#   'total_deaths_per_million': Decimal('465'),
#   'population': Decimal('10095291')},
#  {'country': 'Ecuador',
#   'confirmed': 43378,
#   'new_cases': 258,
#   'deaths': 3642,
#   'recovered': 21020,
#   'active': 18716,
#   'critical': 228,
#   'new_deaths': 21,
#   'total_tests': 127576,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2461'),
#   'total_deaths_per_million': Decimal('207'),
#   'population': Decimal('17624879')},
#  {'country': 'UAE',
#   'confirmed': 39376,
#   'new_cases': 568,
#   'deaths': 281,
#   'recovered': 22275,
#   'active': 16820,
#   'critical': 1,
#   'new_deaths': 5,
#   'total_tests': 2500000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3984'),
#   'total_deaths_per_million': Decimal('28'),
#   'population': Decimal('9882493')},
#  {'country': 'Colombia',
#   'confirmed': 39236,
#   'new_cases': 0,
#   'deaths': 1259,
#   'recovered': 15322,
#   'active': 22655,
#   'critical': 335,
#   'new_deaths': 0,
#   'total_tests': 410719,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('772'),
#   'total_deaths_per_million': Decimal('25'),
#   'population': Decimal('50847406')},
#  {'country': 'Singapore',
#   'confirmed': 38296,
#   'new_cases': 386,
#   'deaths': 25,
#   'recovered': 25368,
#   'active': 12903,
#   'critical': 4,
#   'new_deaths': 0,
#   'total_tests': 408495,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('6549'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('5847399')},
#  {'country': 'Portugal',
#   'confirmed': 34885,
#   'new_cases': 192,
#   'deaths': 1485,
#   'recovered': 21156,
#   'active': 12244,
#   'critical': 55,
#   'new_deaths': 6,
#   'total_tests': 873998,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3421'),
#   'total_deaths_per_million': Decimal('146'),
#   'population': Decimal('10198446')},
#  {'country': 'Egypt',
#   'confirmed': 34079,
#   'new_cases': 0,
#   'deaths': 1237,
#   'recovered': 8961,
#   'active': 23881,
#   'critical': 41,
#   'new_deaths': 0,
#   'total_tests': 135000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('333'),
#   'total_deaths_per_million': Decimal('12'),
#   'population': Decimal('102199634')},
#  {'country': 'Kuwait',
#   'confirmed': 32510,
#   'new_cases': 662,
#   'deaths': 269,
#   'recovered': 21242,
#   'active': 10999,
#   'critical': 166,
#   'new_deaths': 5,
#   'total_tests': 318284,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('7620'),
#   'total_deaths_per_million': Decimal('63'),
#   'population': Decimal('4266300')},
#  {'country': 'Indonesia',
#   'confirmed': 32033,
#   'new_cases': 847,
#   'deaths': 1883,
#   'recovered': 10904,
#   'active': 19246,
#   'critical': 0,
#   'new_deaths': 32,
#   'total_tests': 412980,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('117'),
#   'total_deaths_per_million': Decimal('7'),
#   'population': Decimal('273334499')},
#  {'country': 'Switzerland',
#   'confirmed': 30972,
#   'new_cases': 7,
#   'deaths': 1923,
#   'recovered': 28700,
#   'active': 349,
#   'critical': 29,
#   'new_deaths': 2,
#   'total_tests': 425154,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3580'),
#   'total_deaths_per_million': Decimal('222'),
#   'population': Decimal('8650592')},
#  {'country': 'Ukraine',
#   'confirmed': 27462,
#   'new_cases': 463,
#   'deaths': 797,
#   'recovered': 12195,
#   'active': 14470,
#   'critical': 304,
#   'new_deaths': 9,
#   'total_tests': 431085,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('628'),
#   'total_deaths_per_million': Decimal('18'),
#   'population': Decimal('43748704')},
#  {'country': 'Poland',
#   'confirmed': 27160,
#   'new_cases': 599,
#   'deaths': 1166,
#   'recovered': 12998,
#   'active': 12996,
#   'critical': 160,
#   'new_deaths': 9,
#   'total_tests': 1056396,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('718'),
#   'total_deaths_per_million': Decimal('31'),
#   'population': Decimal('37849071')},
#  {'country': 'Ireland',
#   'confirmed': 25207,
#   'new_cases': 6,
#   'deaths': 1683,
#   'recovered': 22698,
#   'active': 826,
#   'critical': 36,
#   'new_deaths': 4,
#   'total_tests': 348416,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5109'),
#   'total_deaths_per_million': Decimal('341'),
#   'population': Decimal('4934162')},
#  {'country': 'Argentina',
#   'confirmed': 22794,
#   'new_cases': 0,
#   'deaths': 670,
#   'recovered': 7305,
#   'active': 14819,
#   'critical': 274,
#   'new_deaths': 6,
#   'total_tests': 198520,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('505'),
#   'total_deaths_per_million': Decimal('15'),
#   'population': Decimal('45168963')},
#  {'country': 'Philippines',
#   'confirmed': 22474,
#   'new_cases': 579,
#   'deaths': 1011,
#   'recovered': 4637,
#   'active': 16826,
#   'critical': 82,
#   'new_deaths': 8,
#   'total_tests': 441396,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('205'),
#   'total_deaths_per_million': Decimal('9'),
#   'population': Decimal('109483597')},
#  {'country': 'Afghanistan',
#   'confirmed': 20917,
#   'new_cases': 575,
#   'deaths': 369,
#   'recovered': 2171,
#   'active': 18377,
#   'critical': 19,
#   'new_deaths': 12,
#   'total_tests': 48305,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('538'),
#   'total_deaths_per_million': Decimal('9'),
#   'population': Decimal('38865373')},
#  {'country': 'Romania',
#   'confirmed': 20604,
#   'new_cases': 125,
#   'deaths': 1339,
#   'recovered': 14826,
#   'active': 4439,
#   'critical': 146,
#   'new_deaths': 6,
#   'total_tests': 506115,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1071'),
#   'total_deaths_per_million': Decimal('70'),
#   'population': Decimal('19244947')},
#  {'country': 'Dominican Republic',
#   'confirmed': 20126,
#   'new_cases': 526,
#   'deaths': 539,
#   'recovered': 12158,
#   'active': 7429,
#   'critical': 110,
#   'new_deaths': 1,
#   'total_tests': 94511,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1857'),
#   'total_deaths_per_million': Decimal('50'),
#   'population': Decimal('10840829')},
#  {'country': 'Israel',
#   'confirmed': 18032,
#   'new_cases': 169,
#   'deaths': 298,
#   'recovered': 15102,
#   'active': 2632,
#   'critical': 27,
#   'new_deaths': 0,
#   'total_tests': 662916,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1961'),
#   'total_deaths_per_million': Decimal('32'),
#   'population': Decimal('9197590')},
#  {'country': 'Oman',
#   'confirmed': 17486,
#   'new_cases': 604,
#   'deaths': 81,
#   'recovered': 3793,
#   'active': 13612,
#   'critical': 75,
#   'new_deaths': 6,
#   'total_tests': 111376,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3431'),
#   'total_deaths_per_million': Decimal('16'),
#   'population': Decimal('5097088')},
#  {'country': 'Japan',
#   'confirmed': 17141,
#   'new_cases': 0,
#   'deaths': 916,
#   'recovered': 15139,
#   'active': 1086,
#   'critical': 98,
#   'new_deaths': 0,
#   'total_tests': 314483,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('136'),
#   'total_deaths_per_million': Decimal('7'),
#   'population': Decimal('126499051')},
#  {'country': 'Austria',
#   'confirmed': 16968,
#   'new_cases': 66,
#   'deaths': 672,
#   'recovered': 15839,
#   'active': 457,
#   'critical': 17,
#   'new_deaths': 0,
#   'total_tests': 494761,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1885'),
#   'total_deaths_per_million': Decimal('75'),
#   'population': Decimal('9003169')},
#  {'country': 'Panama',
#   'confirmed': 16425,
#   'new_cases': 0,
#   'deaths': 393,
#   'recovered': 10218,
#   'active': 5814,
#   'critical': 84,
#   'new_deaths': 0,
#   'total_tests': 72697,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3811'),
#   'total_deaths_per_million': Decimal('91'),
#   'population': Decimal('4310139')},
#  {'country': 'Bahrain',
#   'confirmed': 15417,
#   'new_cases': 654,
#   'deaths': 27,
#   'recovered': 10326,
#   'active': 5064,
#   'critical': 12,
#   'new_deaths': 1,
#   'total_tests': 374362,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('9085'),
#   'total_deaths_per_million': Decimal('16'),
#   'population': Decimal('1696917')},
#  {'country': 'Bolivia',
#   'confirmed': 13643,
#   'new_cases': 285,
#   'deaths': 465,
#   'recovered': 2086,
#   'active': 11092,
#   'critical': 3,
#   'new_deaths': 11,
#   'total_tests': 37276,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1170'),
#   'total_deaths_per_million': Decimal('40'),
#   'population': Decimal('11662351')},
#  {'country': 'Iraq',
#   'confirmed': 13481,
#   'new_cases': 1115,
#   'deaths': 370,
#   'recovered': 5572,
#   'active': 7539,
#   'critical': 69,
#   'new_deaths': 24,
#   'total_tests': 311980,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('336'),
#   'total_deaths_per_million': Decimal('9'),
#   'population': Decimal('40157701')},
#  {'country': 'Armenia',
#   'confirmed': 13325,
#   'new_cases': 195,
#   'deaths': 211,
#   'recovered': 4099,
#   'active': 9015,
#   'critical': 10,
#   'new_deaths': 11,
#   'total_tests': 70000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4497'),
#   'total_deaths_per_million': Decimal('71'),
#   'population': Decimal('2962906')},
#  {'country': 'Kazakhstan',
#   'confirmed': 12859,
#   'new_cases': 165,
#   'deaths': 56,
#   'recovered': 7376,
#   'active': 5427,
#   'critical': 62,
#   'new_deaths': 3,
#   'total_tests': 965089,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('685'),
#   'total_deaths_per_million': Decimal('3'),
#   'population': Decimal('18761857')},
#  {'country': 'Nigeria',
#   'confirmed': 12486,
#   'new_cases': 0,
#   'deaths': 354,
#   'recovered': 3959,
#   'active': 8173,
#   'critical': 7,
#   'new_deaths': 0,
#   'total_tests': 76802,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('61'),
#   'total_deaths_per_million': Decimal('2'),
#   'population': Decimal('205766196')},
#  {'country': 'Denmark',
#   'confirmed': 11962,
#   'new_cases': 14,
#   'deaths': 593,
#   'recovered': 10792,
#   'active': 577,
#   'critical': 16,
#   'new_deaths': 4,
#   'total_tests': 715100,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2066'),
#   'total_deaths_per_million': Decimal('102'),
#   'population': Decimal('5790943')},
#  {'country': 'Serbia',
#   'confirmed': 11896,
#   'new_cases': 73,
#   'deaths': 250,
#   'recovered': 11348,
#   'active': 298,
#   'critical': 15,
#   'new_deaths': 1,
#   'total_tests': 276810,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1361'),
#   'total_deaths_per_million': Decimal('29'),
#   'population': Decimal('8739407')},
#  {'country': 'S. Korea',
#   'confirmed': 11814,
#   'new_cases': 38,
#   'deaths': 273,
#   'recovered': 10563,
#   'active': 978,
#   'critical': 15,
#   'new_deaths': 0,
#   'total_tests': 1018214,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('230'),
#   'total_deaths_per_million': Decimal('5'),
#   'population': Decimal('51266523')},
#  {'country': 'Algeria',
#   'confirmed': 10265,
#   'new_cases': 111,
#   'deaths': 715,
#   'recovered': 6799,
#   'active': 2751,
#   'critical': 36,
#   'new_deaths': 8,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('234'),
#   'total_deaths_per_million': Decimal('16'),
#   'population': Decimal('43796100')},
#  {'country': 'Ghana',
#   'confirmed': 9910,
#   'new_cases': 272,
#   'deaths': 48,
#   'recovered': 3645,
#   'active': 6217,
#   'critical': 3,
#   'new_deaths': 4,
#   'total_tests': 233734,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('319'),
#   'total_deaths_per_million': Decimal('2'),
#   'population': Decimal('31026938')},
#  {'country': 'Moldova',
#   'confirmed': 9807,
#   'new_cases': 107,
#   'deaths': 353,
#   'recovered': 5738,
#   'active': 3716,
#   'critical': 318,
#   'new_deaths': 12,
#   'total_tests': 63328,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2431'),
#   'total_deaths_per_million': Decimal('87'),
#   'population': Decimal('4034514')},
#  {'country': 'Czechia',
#   'confirmed': 9670,
#   'new_cases': 42,
#   'deaths': 328,
#   'recovered': 6979,
#   'active': 2363,
#   'critical': 9,
#   'new_deaths': 1,
#   'total_tests': 473747,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('903'),
#   'total_deaths_per_million': Decimal('31'),
#   'population': Decimal('10707772')},
#  {'country': 'Norway',
#   'confirmed': 8561,
#   'new_cases': 14,
#   'deaths': 239,
#   'recovered': 8138,
#   'active': 184,
#   'critical': 5,
#   'new_deaths': 1,
#   'total_tests': 262236,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1580'),
#   'total_deaths_per_million': Decimal('44'),
#   'population': Decimal('5418531')},
#  {'country': 'Malaysia',
#   'confirmed': 8329,
#   'new_cases': 7,
#   'deaths': 117,
#   'recovered': 6694,
#   'active': 1518,
#   'critical': 6,
#   'new_deaths': 0,
#   'total_tests': 618360,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('258'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('32338393')},
#  {'country': 'Morocco',
#   'confirmed': 8302,
#   'new_cases': 78,
#   'deaths': 208,
#   'recovered': 7408,
#   'active': 686,
#   'critical': 15,
#   'new_deaths': 0,
#   'total_tests': 322703,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('225'),
#   'total_deaths_per_million': Decimal('6'),
#   'population': Decimal('36881658')},
#  {'country': 'Cameroon',
#   'confirmed': 8060,
#   'new_cases': 152,
#   'deaths': 212,
#   'recovered': 4748,
#   'active': 3100,
#   'critical': 28,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('304'),
#   'total_deaths_per_million': Decimal('8'),
#   'population': Decimal('26497531')},
#  {'country': 'Azerbaijan',
#   'confirmed': 7876,
#   'new_cases': 323,
#   'deaths': 93,
#   'recovered': 4377,
#   'active': 3406,
#   'critical': 66,
#   'new_deaths': 5,
#   'total_tests': 343391,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('777'),
#   'total_deaths_per_million': Decimal('9'),
#   'population': Decimal('10133277')},
#  {'country': 'Australia',
#   'confirmed': 7265,
#   'new_cases': 5,
#   'deaths': 102,
#   'recovered': 6706,
#   'active': 457,
#   'critical': 3,
#   'new_deaths': 0,
#   'total_tests': 1633515,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('285'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('25480378')},
#  {'country': 'Guatemala',
#   'confirmed': 7055,
#   'new_cases': 263,
#   'deaths': 252,
#   'recovered': 1261,
#   'active': 5542,
#   'critical': 5,
#   'new_deaths': 22,
#   'total_tests': 31427,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('394'),
#   'total_deaths_per_million': Decimal('14'),
#   'population': Decimal('17892493')},
#  {'country': 'Finland',
#   'confirmed': 7001,
#   'new_cases': 20,
#   'deaths': 323,
#   'recovered': 5800,
#   'active': 878,
#   'critical': 6,
#   'new_deaths': 0,
#   'total_tests': 203439,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1264'),
#   'total_deaths_per_million': Decimal('58'),
#   'population': Decimal('5540198')},
#  {'country': 'Honduras',
#   'confirmed': 6327,
#   'new_cases': 172,
#   'deaths': 258,
#   'recovered': 712,
#   'active': 5357,
#   'critical': 13,
#   'new_deaths': 8,
#   'total_tests': 21540,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('639'),
#   'total_deaths_per_million': Decimal('26'),
#   'population': Decimal('9893859')},
#  {'country': 'Sudan',
#   'confirmed': 6081,
#   'new_cases': 0,
#   'deaths': 359,
#   'recovered': 2014,
#   'active': 3708,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 401,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('139'),
#   'total_deaths_per_million': Decimal('8'),
#   'population': Decimal('43775253')},
#  {'country': 'Tajikistan',
#   'confirmed': 4609,
#   'new_cases': 80,
#   'deaths': 48,
#   'recovered': 2763,
#   'active': 1798,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('484'),
#   'total_deaths_per_million': Decimal('5'),
#   'population': Decimal('9522265')},
#  {'country': 'Uzbekistan',
#   'confirmed': 4440,
#   'new_cases': 109,
#   'deaths': 18,
#   'recovered': 3357,
#   'active': 1065,
#   'critical': 7,
#   'new_deaths': 1,
#   'total_tests': 748555,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('133'),
#   'total_deaths_per_million': Decimal('0.5'),
#   'population': Decimal('33436477')},
#  {'country': 'Senegal',
#   'confirmed': 4427,
#   'new_cases': 99,
#   'deaths': 49,
#   'recovered': 2699,
#   'active': 1679,
#   'critical': 14,
#   'new_deaths': 0,
#   'total_tests': 49180,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('265'),
#   'total_deaths_per_million': Decimal('3'),
#   'population': Decimal('16711294')},
#  {'country': 'Djibouti',
#   'confirmed': 4278,
#   'new_cases': 71,
#   'deaths': 31,
#   'recovered': 2013,
#   'active': 2234,
#   'critical': 0,
#   'new_deaths': 3,
#   'total_tests': 36497,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4334'),
#   'total_deaths_per_million': Decimal('31'),
#   'population': Decimal('987030')},
#  {'country': 'Guinea',
#   'confirmed': 4117,
#   'new_cases': 0,
#   'deaths': 23,
#   'recovered': 2877,
#   'active': 1217,
#   'critical': 24,
#   'new_deaths': 0,
#   'total_tests': 14407,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('314'),
#   'total_deaths_per_million': Decimal('2'),
#   'population': Decimal('13106296')},
#  {'country': 'DRC',
#   'confirmed': 4106,
#   'new_cases': 90,
#   'deaths': 88,
#   'recovered': 537,
#   'active': 3481,
#   'critical': 0,
#   'new_deaths': 3,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('46'),
#   'total_deaths_per_million': Decimal('1.0'),
#   'population': Decimal('89353804')},
#  {'country': 'Luxembourg',
#   'confirmed': 4040,
#   'new_cases': 1,
#   'deaths': 110,
#   'recovered': 3901,
#   'active': 29,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 88234,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('6461'),
#   'total_deaths_per_million': Decimal('176'),
#   'population': Decimal('625281')},
#  {'country': 'Hungary',
#   'confirmed': 4014,
#   'new_cases': 6,
#   'deaths': 548,
#   'recovered': 2284,
#   'active': 1182,
#   'critical': 21,
#   'new_deaths': 2,
#   'total_tests': 210749,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('415'),
#   'total_deaths_per_million': Decimal('57'),
#   'population': Decimal('9661789')},
#  {'country': 'Nepal',
#   'confirmed': 3762,
#   'new_cases': 314,
#   'deaths': 14,
#   'recovered': 488,
#   'active': 3260,
#   'critical': 0,
#   'new_deaths': 1,
#   'total_tests': 257962,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('129'),
#   'total_deaths_per_million': Decimal('0.5'),
#   'population': Decimal('29100465')},
#  {'country': 'Ivory Coast',
#   'confirmed': 3739,
#   'new_cases': 0,
#   'deaths': 36,
#   'recovered': 1818,
#   'active': 1885,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 31549,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('142'),
#   'total_deaths_per_million': Decimal('1'),
#   'population': Decimal('26330544')},
#  {'country': 'Haiti',
#   'confirmed': 3334,
#   'new_cases': 262,
#   'deaths': 51,
#   'recovered': 24,
#   'active': 3259,
#   'critical': 0,
#   'new_deaths': 1,
#   'total_tests': 7357,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('293'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('11393320')},
#  {'country': 'North Macedonia',
#   'confirmed': 3152,
#   'new_cases': 127,
#   'deaths': 156,
#   'recovered': 1653,
#   'active': 1343,
#   'critical': 34,
#   'new_deaths': 3,
#   'total_tests': 37027,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1513'),
#   'total_deaths_per_million': Decimal('75'),
#   'population': Decimal('2083379')},
#  {'country': 'Thailand',
#   'confirmed': 3119,
#   'new_cases': 7,
#   'deaths': 58,
#   'recovered': 2973,
#   'active': 88,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 468175,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('45'),
#   'total_deaths_per_million': Decimal('0.8'),
#   'population': Decimal('69789262')},
#  {'country': 'El Salvador',
#   'confirmed': 3104,
#   'new_cases': 89,
#   'deaths': 55,
#   'recovered': 1361,
#   'active': 1688,
#   'critical': 92,
#   'new_deaths': 2,
#   'total_tests': 108924,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('479'),
#   'total_deaths_per_million': Decimal('8'),
#   'population': Decimal('6484160')},
#  {'country': 'Gabon',
#   'confirmed': 3101,
#   'new_cases': 0,
#   'deaths': 21,
#   'recovered': 833,
#   'active': 2247,
#   'critical': 13,
#   'new_deaths': 0,
#   'total_tests': 16730,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1396'),
#   'total_deaths_per_million': Decimal('9'),
#   'population': Decimal('2221930')},
#  {'country': 'Greece',
#   'confirmed': 3049,
#   'new_cases': 52,
#   'deaths': 182,
#   'recovered': 1374,
#   'active': 1493,
#   'critical': 10,
#   'new_deaths': 2,
#   'total_tests': 229519,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('292'),
#   'total_deaths_per_million': Decimal('17'),
#   'population': Decimal('10425978')},
#  {'country': 'Kenya',
#   'confirmed': 2872,
#   'new_cases': 105,
#   'deaths': 85,
#   'recovered': 849,
#   'active': 1938,
#   'critical': 7,
#   'new_deaths': 1,
#   'total_tests': 98439,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('53'),
#   'total_deaths_per_million': Decimal('2'),
#   'population': Decimal('53686542')},
#  {'country': 'Bulgaria',
#   'confirmed': 2727,
#   'new_cases': 16,
#   'deaths': 160,
#   'recovered': 1548,
#   'active': 1019,
#   'critical': 12,
#   'new_deaths': 0,
#   'total_tests': 90329,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('392'),
#   'total_deaths_per_million': Decimal('23'),
#   'population': Decimal('6951380')},
#  {'country': 'Bosnia and Herzegovina',
#   'confirmed': 2704,
#   'new_cases': 31,
#   'deaths': 160,
#   'recovered': 2023,
#   'active': 521,
#   'critical': 4,
#   'new_deaths': 1,
#   'total_tests': 71820,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('824'),
#   'total_deaths_per_million': Decimal('49'),
#   'population': Decimal('3281977')},
#  {'country': 'Venezuela',
#   'confirmed': 2377,
#   'new_cases': 0,
#   'deaths': 22,
#   'recovered': 487,
#   'active': 1868,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1343336,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('84'),
#   'total_deaths_per_million': Decimal('0.8'),
#   'population': Decimal('28440650')},
#  {'country': 'Somalia',
#   'confirmed': 2368,
#   'new_cases': 34,
#   'deaths': 84,
#   'recovered': 470,
#   'active': 1814,
#   'critical': 2,
#   'new_deaths': 1,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('149'),
#   'total_deaths_per_million': Decimal('5'),
#   'population': Decimal('15860043')},
#  {'country': 'Croatia',
#   'confirmed': 2247,
#   'new_cases': 0,
#   'deaths': 104,
#   'recovered': 2128,
#   'active': 15,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 68866,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('547'),
#   'total_deaths_per_million': Decimal('25'),
#   'population': Decimal('4106705')},
#  {'country': 'Cuba',
#   'confirmed': 2200,
#   'new_cases': 9,
#   'deaths': 83,
#   'recovered': 1868,
#   'active': 249,
#   'critical': 3,
#   'new_deaths': 0,
#   'total_tests': 120536,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('194'),
#   'total_deaths_per_million': Decimal('7'),
#   'population': Decimal('11327028')},
#  {'country': 'Ethiopia',
#   'confirmed': 2156,
#   'new_cases': 136,
#   'deaths': 27,
#   'recovered': 361,
#   'active': 1768,
#   'critical': 32,
#   'new_deaths': 0,
#   'total_tests': 147735,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('19'),
#   'total_deaths_per_million': Decimal('0.2'),
#   'population': Decimal('114755497')},
#  {'country': 'Mayotte',
#   'confirmed': 2151,
#   'new_cases': 72,
#   'deaths': 25,
#   'recovered': 1654,
#   'active': 472,
#   'critical': 12,
#   'new_deaths': 0,
#   'total_tests': 8150,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('7898'),
#   'total_deaths_per_million': Decimal('92'),
#   'population': Decimal('272336')},
#  {'country': 'Kyrgyzstan',
#   'confirmed': 2032,
#   'new_cases': 25,
#   'deaths': 23,
#   'recovered': 1445,
#   'active': 564,
#   'critical': 5,
#   'new_deaths': 1,
#   'total_tests': 127051,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('312'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('6516817')},
#  {'country': 'Estonia',
#   'confirmed': 1940,
#   'new_cases': 1,
#   'deaths': 69,
#   'recovered': 1683,
#   'active': 188,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 90620,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1463'),
#   'total_deaths_per_million': Decimal('52'),
#   'population': Decimal('1326481')},
#  {'country': 'Maldives',
#   'confirmed': 1916,
#   'new_cases': 13,
#   'deaths': 8,
#   'recovered': 925,
#   'active': 983,
#   'critical': 9,
#   'new_deaths': 0,
#   'total_tests': 28940,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3549'),
#   'total_deaths_per_million': Decimal('15'),
#   'population': Decimal('539886')},
#  {'country': 'Sri Lanka',
#   'confirmed': 1857,
#   'new_cases': 22,
#   'deaths': 11,
#   'recovered': 990,
#   'active': 856,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 76957,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('87'),
#   'total_deaths_per_million': Decimal('0.5'),
#   'population': Decimal('21407678')},
#  {'country': 'CAR',
#   'confirmed': 1850,
#   'new_cases': 216,
#   'deaths': 5,
#   'recovered': 38,
#   'active': 1807,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 15881,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('384'),
#   'total_deaths_per_million': Decimal('1'),
#   'population': Decimal('4823971')},
#  {'country': 'Iceland',
#   'confirmed': 1807,
#   'new_cases': 0,
#   'deaths': 10,
#   'recovered': 1794,
#   'active': 3,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 62795,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5298'),
#   'total_deaths_per_million': Decimal('29'),
#   'population': Decimal('341103')},
#  {'country': 'Lithuania',
#   'confirmed': 1720,
#   'new_cases': 6,
#   'deaths': 71,
#   'recovered': 1331,
#   'active': 318,
#   'critical': 17,
#   'new_deaths': 0,
#   'total_tests': 335686,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('631'),
#   'total_deaths_per_million': Decimal('26'),
#   'population': Decimal('2724301')},
#  {'country': 'South Sudan',
#   'confirmed': 1604,
#   'new_cases': 287,
#   'deaths': 19,
#   'recovered': 15,
#   'active': 1570,
#   'critical': 0,
#   'new_deaths': 5,
#   'total_tests': 3356,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('143'),
#   'total_deaths_per_million': Decimal('2'),
#   'population': Decimal('11185064')},
#  {'country': 'Mali',
#   'confirmed': 1547,
#   'new_cases': 14,
#   'deaths': 92,
#   'recovered': 916,
#   'active': 539,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 3483,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('77'),
#   'total_deaths_per_million': Decimal('5'),
#   'population': Decimal('20206890')},
#  {'country': 'Slovakia',
#   'confirmed': 1530,
#   'new_cases': 2,
#   'deaths': 28,
#   'recovered': 1396,
#   'active': 106,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 189575,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('280'),
#   'total_deaths_per_million': Decimal('5'),
#   'population': Decimal('5459483')},
#  {'country': 'New Zealand',
#   'confirmed': 1504,
#   'new_cases': 0,
#   'deaths': 22,
#   'recovered': 1482,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 294848,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('301'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('5002100')},
#  {'country': 'Slovenia',
#   'confirmed': 1485,
#   'new_cases': 0,
#   'deaths': 109,
#   'recovered': 1359,
#   'active': 17,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 84748,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('714'),
#   'total_deaths_per_million': Decimal('52'),
#   'population': Decimal('2078921')},
#  {'country': 'Guinea-Bissau',
#   'confirmed': 1368,
#   'new_cases': 0,
#   'deaths': 12,
#   'recovered': 153,
#   'active': 1203,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1500,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('696'),
#   'total_deaths_per_million': Decimal('6'),
#   'population': Decimal('1964631')},
#  {'country': 'Lebanon',
#   'confirmed': 1350,
#   'new_cases': 19,
#   'deaths': 30,
#   'recovered': 779,
#   'active': 541,
#   'critical': 6,
#   'new_deaths': 0,
#   'total_tests': 96181,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('198'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('6827207')},
#  {'country': 'Costa Rica',
#   'confirmed': 1342,
#   'new_cases': 24,
#   'deaths': 10,
#   'recovered': 712,
#   'active': 620,
#   'critical': 5,
#   'new_deaths': 0,
#   'total_tests': 29622,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('264'),
#   'total_deaths_per_million': Decimal('2'),
#   'population': Decimal('5091112')},
#  {'country': 'Equatorial Guinea',
#   'confirmed': 1306,
#   'new_cases': 0,
#   'deaths': 12,
#   'recovered': 200,
#   'active': 1094,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 8268,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('933'),
#   'total_deaths_per_million': Decimal('9'),
#   'population': Decimal('1399406')},
#  {'country': 'Albania',
#   'confirmed': 1263,
#   'new_cases': 17,
#   'deaths': 34,
#   'recovered': 945,
#   'active': 284,
#   'critical': 6,
#   'new_deaths': 0,
#   'total_tests': 16357,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('439'),
#   'total_deaths_per_million': Decimal('12'),
#   'population': Decimal('2877983')},
#  {'country': 'Zambia',
#   'confirmed': 1200,
#   'new_cases': 111,
#   'deaths': 10,
#   'recovered': 912,
#   'active': 278,
#   'critical': 1,
#   'new_deaths': 3,
#   'total_tests': 28236,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('65'),
#   'total_deaths_per_million': Decimal('0.5'),
#   'population': Decimal('18345399')},
#  {'country': 'Paraguay',
#   'confirmed': 1145,
#   'new_cases': 10,
#   'deaths': 11,
#   'recovered': 603,
#   'active': 531,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 38942,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('161'),
#   'total_deaths_per_million': Decimal('2'),
#   'population': Decimal('7126730')},
#  {'country': 'Nicaragua',
#   'confirmed': 1118,
#   'new_cases': 0,
#   'deaths': 46,
#   'recovered': 370,
#   'active': 702,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('169'),
#   'total_deaths_per_million': Decimal('7'),
#   'population': Decimal('6619345')},
#  {'country': 'Hong Kong',
#   'confirmed': 1108,
#   'new_cases': 1,
#   'deaths': 4,
#   'recovered': 1049,
#   'active': 55,
#   'critical': 3,
#   'new_deaths': 0,
#   'total_tests': 202930,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('148'),
#   'total_deaths_per_million': Decimal('0.5'),
#   'population': Decimal('7493083')},
#  {'country': 'Madagascar',
#   'confirmed': 1094,
#   'new_cases': 42,
#   'deaths': 9,
#   'recovered': 254,
#   'active': 831,
#   'critical': 10,
#   'new_deaths': 0,
#   'total_tests': 13707,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('40'),
#   'total_deaths_per_million': Decimal('0.3'),
#   'population': Decimal('27638626')},
#  {'country': 'Latvia',
#   'confirmed': 1088,
#   'new_cases': 0,
#   'deaths': 26,
#   'recovered': 781,
#   'active': 281,
#   'critical': 5,
#   'new_deaths': 1,
#   'total_tests': 118322,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('576'),
#   'total_deaths_per_million': Decimal('14'),
#   'population': Decimal('1887332')},
#  {'country': 'Tunisia',
#   'confirmed': 1087,
#   'new_cases': 0,
#   'deaths': 49,
#   'recovered': 982,
#   'active': 56,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 55419,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('92'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('11810540')},
#  {'country': 'Mauritania',
#   'confirmed': 1049,
#   'new_cases': 0,
#   'deaths': 55,
#   'recovered': 108,
#   'active': 886,
#   'critical': 7,
#   'new_deaths': 0,
#   'total_tests': 7654,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('226'),
#   'total_deaths_per_million': Decimal('12'),
#   'population': Decimal('4640624')},
#  {'country': 'Sierra Leone',
#   'confirmed': 1001,
#   'new_cases': 32,
#   'deaths': 49,
#   'recovered': 611,
#   'active': 341,
#   'critical': 0,
#   'new_deaths': 1,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('126'),
#   'total_deaths_per_million': Decimal('6'),
#   'population': Decimal('7965526')},
#  {'country': 'Niger',
#   'confirmed': 973,
#   'new_cases': 0,
#   'deaths': 65,
#   'recovered': 867,
#   'active': 41,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 6196,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('40'),
#   'total_deaths_per_million': Decimal('3'),
#   'population': Decimal('24136909')},
#  {'country': 'Cyprus',
#   'confirmed': 970,
#   'new_cases': 6,
#   'deaths': 18,
#   'recovered': 807,
#   'active': 145,
#   'critical': 4,
#   'new_deaths': 0,
#   'total_tests': 125312,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('804'),
#   'total_deaths_per_million': Decimal('15'),
#   'population': Decimal('1206800')},
#  {'country': 'Burkina Faso',
#   'confirmed': 890,
#   'new_cases': 1,
#   'deaths': 53,
#   'recovered': 765,
#   'active': 72,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('43'),
#   'total_deaths_per_million': Decimal('3'),
#   'population': Decimal('20860538')},
#  {'country': 'Andorra',
#   'confirmed': 852,
#   'new_cases': 0,
#   'deaths': 51,
#   'recovered': 751,
#   'active': 50,
#   'critical': 7,
#   'new_deaths': 0,
#   'total_tests': 3750,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('11028'),
#   'total_deaths_per_million': Decimal('660'),
#   'population': Decimal('77257')},
#  {'country': 'Uruguay',
#   'confirmed': 845,
#   'new_cases': 0,
#   'deaths': 23,
#   'recovered': 730,
#   'active': 92,
#   'critical': 4,
#   'new_deaths': 0,
#   'total_tests': 48432,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('243'),
#   'total_deaths_per_million': Decimal('7'),
#   'population': Decimal('3472988')},
#  {'country': 'Chad',
#   'confirmed': 839,
#   'new_cases': 2,
#   'deaths': 70,
#   'recovered': 685,
#   'active': 84,
#   'critical': 0,
#   'new_deaths': 1,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('51'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('16390384')},
#  {'country': 'Jordan',
#   'confirmed': 831,
#   'new_cases': 23,
#   'deaths': 9,
#   'recovered': 627,
#   'active': 195,
#   'critical': 5,
#   'new_deaths': 0,
#   'total_tests': 228778,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('81'),
#   'total_deaths_per_million': Decimal('0.9'),
#   'population': Decimal('10196546')},
#  {'country': 'Georgia',
#   'confirmed': 812,
#   'new_cases': 3,
#   'deaths': 13,
#   'recovered': 683,
#   'active': 116,
#   'critical': 6,
#   'new_deaths': 0,
#   'total_tests': 67725,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('204'),
#   'total_deaths_per_million': Decimal('3'),
# ...
#  {'country': 'Suriname',
#   'confirmed': 128,
#   'new_cases': 6,
#   'deaths': 2,
#   'recovered': 9,
#   'active': 117,
#   'critical': 1,
#   'new_deaths': 1,
#   'total_tests': 1165,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('218'),
#   'total_deaths_per_million': Decimal('3'),
#   'population': Decimal('586293')},
#  {'country': 'Cambodia',
#   'confirmed': 126,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 123,
#   'active': 3,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 23879,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('8'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('16703435')},
#  {'country': 'Trinidad and Tobago',
#   'confirmed': 117,
#   'new_cases': 0,
#   'deaths': 8,
#   'recovered': 109,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 3409,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('84'),
#   'total_deaths_per_million': Decimal('6'),
#   'population': Decimal('1399209')},
#  {'country': 'Bahamas',
#   'confirmed': 103,
#   'new_cases': 0,
#   'deaths': 11,
#   'recovered': 62,
#   'active': 30,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 2194,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('262'),
#   'total_deaths_per_million': Decimal('28'),
#   'population': Decimal('393000')},
#  {'country': 'Aruba',
#   'confirmed': 101,
#   'new_cases': 0,
#   'deaths': 3,
#   'recovered': 98,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 2179,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('946'),
#   'total_deaths_per_million': Decimal('28'),
#   'population': Decimal('106738')},
#  {'country': 'Monaco',
#   'confirmed': 99,
#   'new_cases': 0,
#   'deaths': 4,
#   'recovered': 93,
#   'active': 2,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 16200,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2524'),
#   'total_deaths_per_million': Decimal('102'),
#   'population': Decimal('39224')},
#  {'country': 'Barbados',
#   'confirmed': 92,
#   'new_cases': 0,
#   'deaths': 7,
#   'recovered': 81,
#   'active': 4,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 5925,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('320'),
#   'total_deaths_per_million': Decimal('24'),
#   'population': Decimal('287354')},
#  {'country': 'Angola',
#   'confirmed': 92,
#   'new_cases': 1,
#   'deaths': 4,
#   'recovered': 38,
#   'active': 50,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 10000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3'),
#   'total_deaths_per_million': Decimal('0.1'),
#   'population': Decimal('32787913')},
#  {'country': 'Burundi',
#   'confirmed': 83,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 45,
#   'active': 37,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 382,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('7'),
#   'total_deaths_per_million': Decimal('0.08'),
#   'population': Decimal('11863908')},
#  {'country': 'Liechtenstein',
#   'confirmed': 82,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 55,
#   'active': 26,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 900,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2151'),
#   'total_deaths_per_million': Decimal('26'),
#   'population': Decimal('38121')},
#  {'country': 'Sint Maarten',
#   'confirmed': 77,
#   'new_cases': 0,
#   'deaths': 15,
#   'recovered': 61,
#   'active': 1,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 470,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1797'),
#   'total_deaths_per_million': Decimal('350'),
#   'population': Decimal('42844')},
#  {'country': 'French Polynesia',
#   'confirmed': 60,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 60,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 4262,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('214'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('280806')},
#  {'country': 'Bhutan',
#   'confirmed': 59,
#   'new_cases': 11,
#   'deaths': 0,
#   'recovered': 14,
#   'active': 45,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 19539,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('77'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('771051')},
#  {'country': 'Macao',
#   'confirmed': 45,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 45,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('69'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('648742')},
#  {'country': 'Botswana',
#   'confirmed': 42,
#   'new_cases': 2,
#   'deaths': 1,
#   'recovered': 24,
#   'active': 17,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 26238,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('18'),
#   'total_deaths_per_million': Decimal('0.4'),
#   'population': Decimal('2348277')},
#  {'country': 'Saint Martin',
#   'confirmed': 41,
#   'new_cases': 0,
#   'deaths': 3,
#   'recovered': 33,
#   'active': 5,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 614,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1062'),
#   'total_deaths_per_million': Decimal('78'),
#   'population': Decimal('38621')},
#  {'country': 'Eritrea',
#   'confirmed': 39,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 39,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('11'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('3543127')},
#  {'country': 'Namibia',
#   'confirmed': 31,
#   'new_cases': 2,
#   'deaths': 0,
#   'recovered': 16,
#   'active': 15,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 4943,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('12'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('2537711')},
#  {'country': 'Gambia',
#   'confirmed': 28,
#   'new_cases': 2,
#   'deaths': 1,
#   'recovered': 21,
#   'active': 6,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1907,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('12'),
#   'total_deaths_per_million': Decimal('0.4'),
#   'population': Decimal('2411580')},
#  {'country': 'St. Vincent Grenadines',
#   'confirmed': 27,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 16,
#   'active': 11,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 638,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('243'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('110918')},
#  {'country': 'Antigua and Barbuda',
#   'confirmed': 26,
#   'new_cases': 0,
#   'deaths': 3,
#   'recovered': 20,
#   'active': 3,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 246,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('266'),
#   'total_deaths_per_million': Decimal('31'),
#   'population': Decimal('97877')},
#  {'country': 'Timor-Leste',
#   'confirmed': 24,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 24,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1568,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('18'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('1316689')},
#  {'country': 'Grenada',
#   'confirmed': 23,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 22,
#   'active': 1,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 3516,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('204'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('112491')},
#  {'country': 'Curaçao',
#   'confirmed': 21,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 15,
#   'active': 5,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 985,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('128'),
#   'total_deaths_per_million': Decimal('6'),
#   'population': Decimal('164051')},
#  {'country': 'New Caledonia',
#   'confirmed': 20,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 19,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 7065,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('70'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('285320')},
#  {'country': 'Belize',
#   'confirmed': 19,
#   'new_cases': 0,
#   'deaths': 2,
#   'recovered': 16,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1741,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('48'),
#   'total_deaths_per_million': Decimal('5'),
#   'population': Decimal('397127')},
#  {'country': 'Laos',
#   'confirmed': 19,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 18,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 8607,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('7268436')},
#  {'country': 'Saint Lucia',
#   'confirmed': 19,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 18,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1204,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('103'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('183575')},
#  {'country': 'Dominica',
#   'confirmed': 18,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 16,
#   'active': 2,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 534,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('250'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('71975')},
#  {'country': 'Fiji',
#   'confirmed': 18,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 18,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 2431,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('20'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('896032')},
#  {'country': 'Saint Kitts and Nevis',
#   'confirmed': 15,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 15,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 408,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('282'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('53175')},
#  {'country': 'Falkland Islands',
#   'confirmed': 13,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 13,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 535,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3744'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('3472')},
#  {'country': 'Greenland',
#   'confirmed': 13,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 13,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 2371,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('229'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('56764')},
#  {'country': 'Turks and Caicos',
#   'confirmed': 12,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 11,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 192,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('310'),
#   'total_deaths_per_million': Decimal('26'),
#   'population': Decimal('38682')},
#  {'country': 'Vatican City',
#   'confirmed': 12,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 12,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('14981'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('801')},
#  {'country': 'Montserrat',
#   'confirmed': 11,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 10,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 61,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2204'),
#   'total_deaths_per_million': Decimal('200'),
#   'population': Decimal('4992')},
#  {'country': 'Seychelles',
#   'confirmed': 11,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 11,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('112'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('98309')},
#  {'country': 'MS Zaandam',
#   'confirmed': 9,
#   'new_cases': 0,
#   'deaths': 2,
#   'recovered': 0,
#   'active': 7,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Western Sahara',
#   'confirmed': 9,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 6,
#   'active': 2,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('15'),
#   'total_deaths_per_million': Decimal('2'),
#   'population': Decimal('596267')},
#  {'country': 'British Virgin Islands',
#   'confirmed': 8,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 7,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 167,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('265'),
#   'total_deaths_per_million': Decimal('33'),
#   'population': Decimal('30218')},
#  {'country': 'Papua New Guinea',
#   'confirmed': 8,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 8,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 4646,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0.9'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('8935183')},
#  {'country': 'Caribbean Netherlands',
#   'confirmed': 7,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 7,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 424,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('267'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('26207')},
#  {'country': 'St. Barth',
#   'confirmed': 6,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 6,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 152,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('608'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('9875')},
#  {'country': 'Lesotho',
#   'confirmed': 4,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 2,
#   'active': 2,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1515,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('2141162')},
#  {'country': 'Anguilla',
#   'confirmed': 3,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 3,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 41,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('200'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('14994')},
#  {'country': 'Saint Pierre Miquelon',
#   'confirmed': 1,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 1,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('173'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('5796')},
#  {'country': 'China',
#   'confirmed': 83040,
#   'new_cases': 4,
#   'deaths': 4634,
#   'recovered': 78341,
#   'active': 65,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('58'),
#   'total_deaths_per_million': Decimal('3'),
#   'population': Decimal('1439323776')}]

# %%
covid.get_status_by_country_name('india')
# Out:
# {'country': 'India',
#  'confirmed': 265869,
#  'new_cases': 8383,
#  'deaths': 7473,
#  'recovered': 129088,
#  'active': 129308,
#  'critical': 8944,
#  'new_deaths': 266,
#  'total_tests': 4774434,
#  'total_tests_per_million': Decimal('0'),
#  'total_cases_per_million': Decimal('193'),
#  'total_deaths_per_million': Decimal('5'),
#  'population': Decimal('1379122578')}

# %%
covid.list_countries()
# Out:
# ['north america',
#  'south america',
#  'europe',
#  'asia',
#  'africa',
#  'oceania',
#  '',
#  'world',
#  'usa',
#  'brazil',
#  'russia',
#  'spain',
#  'uk',
#  'india',
#  'italy',
#  'peru',
#  'germany',
#  'iran',
#  'turkey',
#  'france',
#  'chile',
#  'mexico',
#  'saudi arabia',
#  'pakistan',
#  'canada',
#  'qatar',
#  'bangladesh',
#  'belgium',
#  'south africa',
#  'belarus',
#  'netherlands',
#  'sweden',
#  'ecuador',
#  'uae',
#  'colombia',
#  'singapore',
#  'portugal',
#  'egypt',
#  'kuwait',
#  'indonesia',
#  'switzerland',
#  'ukraine',
#  'poland',
#  'ireland',
#  'argentina',
#  'philippines',
#  'afghanistan',
#  'romania',
#  'dominican republic',
#  'israel',
#  'oman',
#  'japan',
#  'austria',
#  'panama',
#  'bahrain',
#  'bolivia',
#  'iraq',
#  'armenia',
#  'kazakhstan',
#  'nigeria',
#  'denmark',
#  'serbia',
#  's. korea',
#  'algeria',
#  'ghana',
#  'moldova',
#  'czechia',
#  'norway',
#  'malaysia',
#  'morocco',
#  'cameroon',
#  'azerbaijan',
#  'australia',
#  'guatemala',
#  'finland',
#  'honduras',
#  'sudan',
#  'tajikistan',
#  'uzbekistan',
#  'senegal',
#  'djibouti',
#  'guinea',
#  'drc',
#  'luxembourg',
#  'hungary',
#  'nepal',
#  'ivory coast',
#  'haiti',
#  'north macedonia',
#  'thailand',
#  'el salvador',
#  'gabon',
#  'greece',
#  'kenya',
#  'bulgaria',
#  'bosnia and herzegovina',
#  'venezuela',
#  'somalia',
#  'croatia',
#  'cuba',
#  'ethiopia',
#  'mayotte',
#  'kyrgyzstan',
#  'estonia',
#  'maldives',
#  'sri lanka',
#  'car',
#  'iceland',
#  'lithuania',
#  'south sudan',
#  'mali',
#  'slovakia',
#  'new zealand',
#  'slovenia',
#  'guinea-bissau',
#  'lebanon',
#  'costa rica',
#  'equatorial guinea',
#  'albania',
#  'zambia',
#  'paraguay',
#  'nicaragua',
#  'hong kong',
#  'madagascar',
#  'latvia',
#  'tunisia',
#  'mauritania',
#  'sierra leone',
#  'niger',
#  'cyprus',
#  'burkina faso',
#  'andorra',
#  'uruguay',
#  'chad',
#  'jordan',
#  'georgia',
#  'french guiana',
#  'diamond princess',
#  'san marino',
#  'congo',
#  'uganda',
#  'malta',
#  'jamaica',
#  'cabo verde',
#  'channel islands',
#  'sao tome and principe',
#  'tanzania',
#  'togo',
#  'yemen',
#  'réunion',
#  'palestine',
#  'rwanda',
#  'taiwan',
#  'malawi',
#  'mozambique',
#  'liberia',
#  'eswatini',
#  'mauritius',
#  'isle of man',
#  'vietnam',
#  'montenegro',
#  'benin',
#  'zimbabwe',
#  'libya',
#  'myanmar',
#  'martinique',
#  'mongolia',
#  'faeroe islands',
#  'gibraltar',
#  'guadeloupe',
#  'cayman islands',
#  'guyana',
#  'syria',
#  'bermuda',
#  'brunei',
#  'comoros',
#  'suriname',
#  'cambodia',
#  'trinidad and tobago',
#  'bahamas',
#  'aruba',
#  'monaco',
#  'barbados',
#  'angola',
#  'burundi',
#  'liechtenstein',
#  'sint maarten',
#  'french polynesia',
#  'bhutan',
#  'macao',
#  'botswana',
#  'saint martin',
#  'eritrea',
#  'namibia',
#  'gambia',
#  'st. vincent grenadines',
#  'antigua and barbuda',
#  'timor-leste',
#  'grenada',
#  'curaçao',
#  'new caledonia',
#  'belize',
#  'laos',
#  'saint lucia',
#  'dominica',
#  'fiji',
#  'saint kitts and nevis',
#  'falkland islands',
#  'greenland',
#  'turks and caicos',
#  'vatican city',
#  'montserrat',
#  'seychelles',
#  'ms zaandam',
#  'western sahara',
#  'british virgin islands',
#  'papua new guinea',
#  'caribbean netherlands',
#  'st. barth',
#  'lesotho',
#  'anguilla',
#  'saint pierre miquelon',
#  'china']

# %%
print(covid.get_status_by_country_name('india').get('recovered'))
# Out:
# 129088

# %%
country = str(input("Enter the country you want the data of : "))
# Out:
# Enter the country you want the data of : USA

# %%
import pprint

pp = pprint.PrettyPrinter(indent=4)
pp.pprint(covid.get_status_by_country_name(country))
# Out:
# {   'active': 1138564,
#     'confirmed': 2018552,
#     'country': 'USA',
#     'critical': 16897,
#     'deaths': 112844,
#     'new_cases': 11103,
#     'new_deaths': 375,
#     'population': Decimal('330880530'),
#     'recovered': 767144,
#     'total_cases_per_million': Decimal('6101'),
#     'total_deaths_per_million': Decimal('341'),
#     'total_tests': 21558358,
#     'total_tests_per_million': Decimal('0')}
